# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов" data-toc-modified-id="Переименование-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименование столбцов</a></span></li><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с пропусками</a></span></li><li><span><a href="#Смена-типов-данных" data-toc-modified-id="Смена-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Смена типов данных</a></span></li><li><span><a href="#Работа-с-дубликатами" data-toc-modified-id="Работа-с-дубликатами-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Работа с дубликатами</a></span></li></ul></li><li><span><a href="#Добавление-новых-столбцов" data-toc-modified-id="Добавление-новых-столбцов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Добавление новых столбцов</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров" data-toc-modified-id="Изучение-параметров-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров</a></span><ul class="toc-item"><li><span><a href="#Параметр-&quot;Общая-площадь&quot;" data-toc-modified-id="Параметр-&quot;Общая-площадь&quot;-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Параметр "Общая площадь"</a></span></li><li><span><a href="#Параметр-&quot;Жилая-площадь&quot;" data-toc-modified-id="Параметр-&quot;Жилая-площадь&quot;-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Параметр "Жилая площадь"</a></span></li><li><span><a href="#Параметр-&quot;Площадь-кухни&quot;" data-toc-modified-id="Параметр-&quot;Площадь-кухни&quot;-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Параметр "Площадь кухни"</a></span></li><li><span><a href="#Параметр-&quot;Цена-объекта&quot;" data-toc-modified-id="Параметр-&quot;Цена-объекта&quot;-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Параметр "Цена объекта"</a></span></li><li><span><a href="#Параметр-&quot;Количество-комнат&quot;" data-toc-modified-id="Параметр-&quot;Количество-комнат&quot;-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Параметр "Количество комнат"</a></span></li><li><span><a href="#Параметр-&quot;Высота-потолков&quot;" data-toc-modified-id="Параметр-&quot;Высота-потолков&quot;-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Параметр "Высота потолков"</a></span></li><li><span><a href="#Параметр-&quot;Тип-этажа-квартиры&quot;" data-toc-modified-id="Параметр-&quot;Тип-этажа-квартиры&quot;-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Параметр "Тип этажа квартиры"</a></span></li><li><span><a href="#Параметр-&quot;Общее-количество-этажей-в-доме&quot;" data-toc-modified-id="Параметр-&quot;Общее-количество-этажей-в-доме&quot;-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span>Параметр "Общее количество этажей в доме"</a></span></li><li><span><a href="#Параметр-&quot;Расстояние-до-центра-города-в-метрах&quot;" data-toc-modified-id="Параметр-&quot;Расстояние-до-центра-города-в-метрах&quot;-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span>Параметр "Расстояние до центра города в метрах"</a></span></li><li><span><a href="#Параметр-&quot;Расстояние-до-ближайшего-парка&quot;" data-toc-modified-id="Параметр-&quot;Расстояние-до-ближайшего-парка&quot;-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span>Параметр "Расстояние до ближайшего парка"</a></span></li></ul></li><li><span><a href="#Изучение-скорости-продажи-квартиры" data-toc-modified-id="Изучение-скорости-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение скорости продажи квартиры</a></span></li><li><span><a href="#Факторы,-влияющие-на-стоимость" data-toc-modified-id="Факторы,-влияющие-на-стоимость-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Факторы, влияющие на стоимость</a></span></li><li><span><a href="#Средняя-цена-м2" data-toc-modified-id="Средняя-цена-м2-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средняя цена м2</a></span></li><li><span><a href="#Стоимость-кв-в-зависимости-от-близости-к-центру" data-toc-modified-id="Стоимость-кв-в-зависимости-от-близости-к-центру-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Стоимость кв в зависимости от близости к центру</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.
#
# Описание данных:
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м);
# - balcony — число балконов;
# - ceiling_height — высота потолков (м);
# - cityCenters_nearest — расстояние до центра города (м);
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия);
# - first_day_exposition — дата публикации;
# - floor — этаж;
# - floors_total — всего этажей в доме;
# - is_apartment — апартаменты (булев тип);
# - kitchen_area — площадь кухни в квадратных метрах (м²);
# - last_price — цена на момент снятия с публикации;
# - living_area — жилая площадь в квадратных метрах (м²);
# - locality_name — название населённого пункта;
# - open_plan — свободная планировка (булев тип);
# - parks_around3000 — число парков в радиусе 3 км;
# - parks_nearest — расстояние до ближайшего парка (м);
# - ponds_around3000 — число водоёмов в радиусе 3 км;
# - ponds_nearest — расстояние до ближайшего водоёма (м);
# - rooms — число комнат;
# - studio — квартира-студия (булев тип);
# - total_area — общая площадь квартиры в квадратных метрах (м²);
# - total_images — число фотографий квартиры в объявлении.
#
# Предлагаю следующий план работы:
#
# 1. Предварительно познакомимся с данными, обработаем таблицу на наличие явных/неявных дубликатов, пропусков и пр., добавим столбцы, необходимые для дальнейшего исследования
# 2. Изучим данные таблицы по столбцам, избавимся от выбросов, подготовим датафрейм к дальнейшим вычислениям
# 3. Посчитаем, как быстро продаются квартиры
# 4. Определим факторы, которые больше всего влияют на рыночную стоимость квартиры
# 5. Посчитаем среднюю цену одного квадратного метра в ряде населенных пунктах с наибольшим количеством объявлений

# %% [markdown]
# ### Общая информация

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
df.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# **Предварительно ознакомились с данными. Заметили первые аномалии: общая площадь, равная 900 м2, 100-метровые потолки, и квартиры с нулевым значением комнат и т.д. Также видно большое количество пропусков в данных, и не везде правильно указаны типы данных, к примеру, в столбце с датой. Наименование одного из столбцов не соответствует snake_case.**

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Переименование столбцов

# %%
df = df.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 'parks_around3000': 'parks_around_3000', 'ponds_around3000': 'ponds_around_3000'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# #### Работа с пропусками

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# is_apartment            20924
# parks_nearest           15620
# ponds_nearest           14589
# balcony                 11519
# ceiling_height           9195
# airports_nearest         5542
# city_centers_nearest     5519
# ponds_around_3000        5518
# parks_around_3000        5518
# days_exposition          3181
# kitchen_area             2278
# living_area              1903
# floors_total               86
# locality_name              49
# total_images                0
# last_price                  0
# studio                      0
# floor                       0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# open_plan                   0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False).plot.bar(figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
test_df = df.isna().sum()/len(df)*100
test_df.sort_values(ascending=False)
# Out:
# is_apartment            88.290645
# parks_nearest           65.909954
# ponds_nearest           61.559559
# balcony                 48.605426
# ceiling_height          38.799105
# airports_nearest        23.384953
# city_centers_nearest    23.287902
# ponds_around_3000       23.283683
# parks_around_3000       23.283683
# days_exposition         13.422507
# kitchen_area             9.612220
# living_area              8.029875
# floors_total             0.362885
# locality_name            0.206760
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# floor                    0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.50     3515
# 2.60     1646
# 2.70     1574
# 3.00     1112
# 2.80      993
#          ...
# 4.25        1
# 3.39        1
# 3.93        1
# 10.30       1
# 4.65        1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# **Так как высота потолков, как правило, регламентирована в определенных пределах и большая часть квартир с потолком в районе 2.5-2.7м, предлагаю пропуски в этом столбце заменить на среднее значение.**

# %%
df.loc[df['ceiling_height'].isna(),['ceiling_height']] = df['ceiling_height'].mean()

# %% [markdown]
# **Почти половина пропусков наблюдается в столбце 'balcony', предполагаем, что балконов в данных квартирах нет, поэтому указываем значение 0 на месте пропусков.**

# %%
df['balcony'] = df['balcony'].fillna(0)

# %% [markdown]
# **Наблюдается 88% пропущенных значений в столбце is_apartment. Изначально, предположила, что доля апартаментов довольна низкая по сравнению с обычнымим квартирами, поэтому собственники квартир просто пропускали этот пункт при заполнении объявления. Проверила, что в данном столбце есть как значения True, так и False. Не стала заполнять пропуски значением False, т.к. сомнительно, что на 23669 объявлений только 50 шт. с апартаментами.**

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
df.loc[df['is_apartment'].isna(), ['is_apartment']] = df['is_apartment'].fillna(False)

# %%
df['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# **Попробуем заполнить пропуски в столбцах living_area и kitchen_area. Для этого рассчитаем медианную долю жилой площади и кухни для строк, где заполнены все столбцы. Далее экстраполируем полученную долю на пропуски.**

# %% [markdown]
# Прежде всего замечу, что исходные данные некорректны:, например сумма жилой площади и площади кухни в строке 7239 изначально больше, чем общая площадь.

# %%
df.iloc[7239]
# Out:
# total_images                             10
# last_price                        9990000.0
# total_area                             90.0
# first_day_exposition    2016-06-13T00:00:00
# rooms                                     3
# ceiling_height                          3.1
# floors_total                            6.0
# living_area                            76.4
# floor                                     6
# is_apartment                          False
# studio                                False
# open_plan                             False
# kitchen_area                           43.4
# balcony                                 3.0
# locality_name               Санкт-Петербург
# airports_nearest                    33358.0
# city_centers_nearest                13171.0
# parks_around_3000                       0.0
# parks_nearest                           NaN
# ponds_around_3000                       2.0
# ponds_nearest                         118.0
# ...

# %%
square_perc = df[(~df['living_area'].isna())&(~df['kitchen_area'].isna())].reset_index(drop=True)
square_perc
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# 4                10   2890000.0       30.40  2018-09-10T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 20977             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 20978             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 20979             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 20980            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 20981             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# **Рассчитаем долю жилой площади и кухни**

# %%
square_perc['living_kitchen'] = (square_perc['living_area'] + square_perc['kitchen_area'])/square_perc['total_area']

# %%
square_perc['living_kitchen'].median()
# Out:
# 0.75

# %% [markdown]
# *Доля нежилой площади 25%*

# %% [markdown]
# **Рассчитаем долю нежилой площади и кухни**

# %%
square_perc['non_living_kitchen'] = (square_perc['total_area']*0.25 + square_perc['kitchen_area'])/square_perc['total_area']

# %%
square_perc['non_living_kitchen'].median()
# Out:
# 0.421875

# %% [markdown]
# *Доля жилой площади 57.8125%*

# %% [markdown]
# **Рассчитаем долю нежилой и жилой площади**

# %%
square_perc['non_living_living'] = (square_perc['total_area']*0.25 + square_perc['total_area']*0.578125)/square_perc['total_area']

# %%
square_perc['non_living_living'].median()
# Out:
# 0.828125

# %% [markdown]
# *Доля кухни 17.1875*

# %%
df.loc[(df['living_area'].isna()) & (df['kitchen_area'].isna())] = df.loc[(df['living_area'].isna()) & (df['kitchen_area'].isna())].fillna({'living_area': df['total_area']* 0.578125, 'kitchen_area': df['total_area']*0.171875})

# %%
df['diff'] = df['total_area'] - df['kitchen_area'] - df['living_area']

# %%
df['diff'].value_counts().sort_index()
# Out:
# -29.80     1
# -20.30     1
# -20.00     1
# -19.00     1
# -16.47     1
#           ..
#  227.00    1
#  289.40    1
#  290.00    1
#  325.40    1
#  378.30    1
# Name: diff, Length: 3255, dtype: int64

# %%
df['living_area'].isna().sum()
# Out:
# 439

# %%
df['kitchen_area'].isna().sum()
# Out:
# 814

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23260 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          22885 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **Столбцы locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest имеют большую долю пропусков в данных. Полагаю, необходимо обратиться к коллегам, чтобы проверить корректность выгрузки, поскольку в условии задачи сказано, что часть данных подгружается автоматически на основе геосервисов.
# Пропуски в столбце days_exposition возможны, т.к. объявления еще не сняты с публикации. Опять-таки необходимо уточнить у коллег, верна ли выгрузка. Столбец total_floors оставляем с пропусками, т.к. заполнять средним или медианной считаю некорректным**

# %% [markdown]
# #### Смена типов данных

# %% [markdown]
# **В столбце 'first_day_exposition' необходимо поменять тип данных с object на datetime. Также необходимо поменять тип данных с float на int в столбцах 'floors_total', 'balcony', 'days_exposition', т.к. значения этих столбцов не могут быть дробными.**

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
#df['days_exposition'] = df['days_exposition'].astype('int', errors='ignore')
#df['floors_total'] = df['floors_total'].astype('int', errors='ignore')
#df['balcony'] = df['balcony'].astype('int', errors='ignore')

# 1. Не понимаю, почему в данном коде при errors='coerce' выдает ошибку?
# 2.в floors_total и days_exposition не меняет тип данных, а balcony меняет (это из-за пропущенных значений?)?

# %%
df['days_exposition'] = pd.to_numeric(df['days_exposition'], errors='coerce')
df['days_exposition'] = df['days_exposition'].astype('int', errors='ignore')
df['floors_total'] = pd.to_numeric(df['floors_total'], errors='coerce')
df['floors_total'] = df['floors_total'].astype('int', errors='ignore')

# %%
df['days_exposition'].unique()
# Out:
# array([  nan,   81.,  558., ..., 1360., 1007.,  971.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23260 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          22885 non-null  float64
#  13  balcony               23699 non-null  float64
# ...

# %% [markdown]
# #### Работа с дубликатами

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df['locality_name'].sort_values().unique())
# Out:
# 365

# %%
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')

# %%
df['locality_name'] = df['locality_name'].str.replace('поселок городского типа','поселок')

# %%
df['locality_name'] = df['locality_name'].str.replace('городской поселок','поселок')

# %%
len(df['locality_name'].sort_values().unique())
# Out:
# 323

# %% [markdown]
# **Явных дубликатов нет. Убрали неявные дубликаты путем приведения к единому формату написания некоторых слов/мест жительства.**

# %% [markdown]
# ### Добавление новых столбцов

# %%
df['price_per_meter'] = round(df['last_price'] / df['total_area'], 2)

# %%
df['day_exposition'] = df['first_day_exposition'].dt.weekday

# %%
df['month_exposition'] = pd.DatetimeIndex(df['first_day_exposition']).month

# %%
df['year_exposition'] = pd.DatetimeIndex(df['first_day_exposition']).year

# %%
def type_floor(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    if floor != floors_total and floor != 1:
        return 'другие'

# %%
df['type_floor'] = df.apply(type_floor, axis=1)

# %%
df.groupby('type_floor')['type_floor'].count()
# Out:
# type_floor
# другие       17446
# первый        2917
# последний     3336
# Name: type_floor, dtype: int64

# %%
df['city_centre_km'] = df['city_centers_nearest'].apply(lambda x: x//1000)
df.loc[:,['city_centers_nearest', 'city_centre_km']]
# Out:
#        city_centers_nearest  city_centre_km
# 0                   16028.0            16.0
# 1                   18603.0            18.0
# 2                   13933.0            13.0
# 3                    6800.0             6.0
# 4                    8098.0             8.0
# ...                     ...             ...
# 23694                4232.0             4.0
# 23695                   NaN             NaN
# 23696                   NaN             NaN
# 23697               10364.0            10.0
# 23698                   NaN             NaN
#
# [23699 rows x 2 columns]

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0        2.700000          16.0    51.000000      8        False  ...
# 1        2.771499          11.0    18.600000      1        False  ...
# 2        2.771499           5.0    34.300000      4        False  ...
# 3        2.771499          14.0    91.921875      9        False  ...
# 4        3.030000          14.0    32.000000     13        False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition   diff price_per_meter  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23260 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          22885 non-null  float64
#  13  balcony               23699 non-null  float64
# ...

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров
# Изучить перечисленные ниже параметры объектов и построить отдельные гистограммы для каждого из этих параметров. Если природа аномалии понятна и данные действительно искажены, то восстановить корректное значение. В противном случае удалить редкие и выбивающиеся значения.
# Список параметров:
# общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего парка
# Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# ##### Параметр "Общая площадь"

# %%
df['total_area'].hist(bins=10,range=(0, 450))
# Out:
# <AxesSubplot:>

# %%
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
def find_iqr(x):
    q75, q25 = np.percentile(x, [75, 25])   
    return np.subtract(q75, q25)

# %%
IQR = find_iqr(df['total_area'])
IQR
# Out:
# 29.900000000000006

# %%
sns.boxplot(x=df['total_area'])
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
df[df['total_area'] >= find_iqr(df['total_area'])*1.5 + 69.9].sort_values('total_area').head(30)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11094            13  10200000.0      114.80           2018-07-19      3
# 15727            19  11500000.0      114.80           2018-03-07      3
# 13370            11   9500000.0      114.80           2018-11-21      5
# 3561              5  12300000.0      115.00           2017-08-09      3
# 22550             2   5800000.0      115.00           2017-09-12      2
# 4659              1   1650000.0      115.00           2019-02-28      5
# 3525             12  10700000.0      115.00           2016-06-08      3
# 3253             10   9500000.0      115.00           2016-11-13      4
# 11683             8  10800000.0      115.00           2017-04-17      3
# 6287             11  12800000.0      115.00           2019-01-22      3
# 2414             20  29500000.0      115.00           2017-07-21      3
# 17652             8  12000000.0      115.00           2015-10-23      3
# ...

# %%
new_df = df[df['total_area'] <= 10*math.ceil((find_iqr(df['total_area'])*1.5 + 69.9)/10)].reset_index(drop=True)
new_df.shape
# Out:
# (22637, 29)

# %%
sns.boxplot(x=new_df['total_area'])
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
new_df['total_area'].describe()
# Out:
# count    22637.000000
# mean        54.861196
# std         20.098237
# min         12.000000
# 25%         39.500000
# 50%         50.500000
# 75%         66.000000
# max        120.000000
# Name: total_area, dtype: float64

# %%
find_iqr(new_df['total_area'])
# Out:
# 26.5

# %% [markdown]
# **Мы построили гистограмму для столбца total_area и обнаружили, что пик приходится на квартиры 40-90 м2. Также увидели единичное аномально большое значение в 900 м2. Мы также построили диаграму размаха и увидели, что медиана не стремится к высоким и аномально высоким значениям и в целом отражает реальную картину. Исходя из практики, можно было откинуть квартиры с общей площадью меньше 25м2, но их доля незначительна и они не попадают в выбросы, поэтому оставляем.  Все выбросы за пределами усов ящика справа удалены. Получили новую таблицу new_df и продолжаем работу с ней.**

# %% [markdown]
# ##### Параметр "Жилая площадь"

# %%
new_df['living_area'].hist(bins=10,range=(0, 200))
# Out:
# <AxesSubplot:>

# %%
new_df['living_area'].describe()
# Out:
# count    22237.000000
# mean        31.351287
# std         13.754397
# min          2.000000
# 25%         18.600000
# 50%         29.900000
# 75%         40.200000
# max        101.000000
# Name: living_area, dtype: float64

# %%
new_df.boxplot('living_area')
# Out:
# <AxesSubplot:>

# %%
p25 = np.percentile(new_df.loc[~new_df['living_area'].isna(), 'living_area'], 25)
p25
# Out:
# 18.6

# %%
p75 = np.percentile(new_df.loc[~new_df['living_area'].isna(), 'living_area'], 75)
p75
# Out:
# 40.2

# %%
IQR = p75-p25
IQR
# Out:
# 21.6

# %%
new_df.query('living_area < 18.5').sort_values('living_area').head(20)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 13287            20   6350000.0        52.0           2018-02-06      2
# 20788             0   2330000.0        23.0           2018-01-01      0
# 3077              7   4440000.0        41.0           2017-07-02      1
# 16800            11   2680000.0        22.0           2018-08-11      0
# 20964            15   6100000.0        77.6           2019-02-28      4
# 15710            13   3799000.0        31.0           2018-04-12      1
# 18388            19   4050000.0        33.0           2018-10-15      1
# 18671             3   1850000.0        13.0           2019-03-11      1
# 17165             3   1400000.0        13.0           2017-12-03      1
# 18683             2   1686000.0        13.2           2018-12-17      1
# 20057             7   8900000.0        50.6           2018-10-22      2
# 22170            12   4800000.0        37.0           2016-02-24      1
# ...

# %% [markdown]
# **Также предлагаю не удалять здесь выбросы, т.к. возможно, в жилой площади в студиях или европланировках учитывают площадь кухни. Также, смущает минимальный размер жилой площади в 2 м2, но доля таких значений мала, как следствие, это не должно сильно влиять на выборку, поэтому оставляем эти данные как есть.**

# %% [markdown]
# ##### Параметр "Площадь кухни"

# %%
new_df['kitchen_area'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
new_df['kitchen_area'].describe()
# Out:
# count    21846.000000
# mean         9.935448
# std          4.453122
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.300000
# max         64.000000
# Name: kitchen_area, dtype: float64

# %%
sns.boxplot(x=new_df['kitchen_area'])
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %%
p25 = np.percentile(new_df.loc[~new_df['kitchen_area'].isna(), 'kitchen_area'], 25)
p75 = np.percentile(new_df.loc[~new_df['kitchen_area'].isna(), 'kitchen_area'], 75)

# %% [markdown]
# **Т.к. в реальности площадь кухни, как правило, учитывается в жилой площади, оставим данные. Редко где в планировках, например в европланировках или студиях, учитывается площадь кухни отдельно.**

# %% [markdown]
# ##### Параметр "Цена объекта"

# %%
new_df['last_price'].hist(range=(0,30000000))
# Out:
# <AxesSubplot:>

# %%
new_df['last_price'].describe()
# Out:
# count    2.263700e+04
# mean     5.383598e+06
# std      3.543451e+06
# min      1.219000e+04
# 25%      3.390000e+06
# 50%      4.500000e+06
# 75%      6.350000e+06
# max      8.200000e+07
# Name: last_price, dtype: float64

# %%
sns.boxplot(x=new_df['last_price'])
# Out:
# <AxesSubplot:xlabel='last_price'>

# %%
IQR = find_iqr(new_df['last_price'])
IQR_extra = IQR*1.5+6350006
IQR_extra
# Out:
# 10790006.0

# %%
max_price = new_df.query('last_price > @IQR_extra').sort_values('last_price')
max_price.head(20)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21900            20  10800000.0        67.8           2019-02-26      2
# 11751            16  10800000.0        69.0           2016-09-13      2
# 8528             14  10800000.0       118.0           2015-07-22      5
# 12318            20  10800000.0        76.6           2018-08-22      2
# 12325            21  10800000.0        70.6           2017-09-26      2
# 17705             3  10800000.0        86.0           2016-06-24      4
# 5639             18  10800000.0        91.3           2018-07-19      4
# 20288            20  10800000.0        95.0           2017-08-11      3
# 11155             8  10800000.0       115.0           2017-04-17      3
# 12775            12  10800000.0       108.0           2015-01-21      4
# 17577             7  10800000.0        87.0           2018-09-02      3
# 7945             17  10800000.0        80.2           2018-09-20      3
# ...

# %%
max_price.shape
# Out:
# (1466, 29)

# %%
new_df.query('last_price > @IQR_extra')['total_area'].median()
# Out:
# 94.13

# %%
new_df.query('last_price >  @IQR_extra')['total_area'].min()
# Out:
# 25.0

# %%
new_df.query('last_price >  @IQR_extra')['total_area'].max()
# Out:
# 120.0

# %%
new_df = new_df[new_df['last_price'] < IQR_extra]
new_df.shape
# Out:
# (21171, 29)

# %% [markdown]
# **Мы проанализировали данные в столбце last_price. Увидели, что пик по цене квартир приходится на 3-6 млн. Мы также посмотрели на срез выбросов (значений, выходящих за усы боксплота), их доля составляет 4,9% от общих данных. Т.к. доля не велика, но может отрицательно влиять на среднее, мы убираем выбросы. Также, вполне возможно, что эти квартиры оценены не совсем адекватно, т.к. мы видим, что квартира в 25 м2 стоит дороже, чем большинство остальных квартир в датафрейме, а самая дорогая квартира в 48000000 не является самой большой по квадратуре, хотя существенно отличается по цене.**

# %% [markdown]
# ##### Параметр "Количество комнат"

# %%
new_df['rooms'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['rooms'].describe()
# Out:
# count    21171.000000
# mean         1.904398
# std          0.890524
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %%
sns.boxplot(x=new_df['rooms'])
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
new_df.query('rooms == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 135               1   2450000.0       27.00           2017-03-30      0
# 330               4   2320000.0       25.00           2017-09-27      0
# 418               8   2480000.0       27.11           2018-03-12      0
# 483               0   3375000.0       34.40           2017-03-28      0
# 577               2   1850000.0       25.00           2019-02-20      0
# ...             ...         ...         ...                  ...    ...
# 22172             7   3200000.0       26.00           2017-09-01      0
# 22393             0   2500000.0       27.70           2017-09-28      0
# 22499            15   3350000.0       26.00           2018-09-07      0
# 22533            10   1450000.0       29.00           2017-11-11      0
# 22577             8   2350000.0       26.00           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
new_df['rooms'] = new_df['rooms'].where(new_df['rooms'] != 0, 1)

# %%
new_df['rooms'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['rooms'].describe()
# Out:
# count    21171.000000
# mean         1.913608
# std          0.875828
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# **Мы построили гистограмму количества комнат. Обнаружили 195 квартир с 0 количеством комнат. Полагаю, что эта ошибка могла быть в квартирах-студиях, о чем говорит даже квадратура данных квартир. Хоть и доля таких значений небольшая, для дальнейших более корректных расчетов исправила количество комнат с 0 на 1. Также, смотря на график ящик с усами, мы видим, что аномальных значений нет. Аномальное значение в 19 комнат ушло с корректировкой общей квадратуры ранее. Поэтому никакие данные удалять не будем.**

# %% [markdown]
# ##### Параметр "Высота потолков"

# %%
new_df['ceiling_height'].hist(range=(0, 32))
# Out:
# <AxesSubplot:>

# %%
new_df['ceiling_height'].describe()
# Out:
# count    21171.000000
# mean         2.742924
# std          0.789657
# min          1.000000
# 25%          2.600000
# 50%          2.771499
# 75%          2.771499
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
sns.boxplot(x=new_df['ceiling_height'])
# Out:
# <AxesSubplot:xlabel='ceiling_height'>

# %%
new_df['ceiling_height'].describe()
# Out:
# count    21171.000000
# mean         2.742924
# std          0.789657
# min          1.000000
# 25%          2.600000
# 50%          2.771499
# 75%          2.771499
# max         32.000000
# Name: ceiling_height, dtype: float64

# %%
new_df['ceiling_height'] = new_df['ceiling_height'].apply(lambda x: x/10 if x >= 10 else x)

# %%
new_df['ceiling_height']. describe()
# Out:
# count    21171.000000
# mean         2.717443
# std          0.197414
# min          1.000000
# 25%          2.600000
# 50%          2.771499
# 75%          2.771499
# max          8.300000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# **Мы проанализировали высоту потолков. Первоначально, были обнаружены значения потолков, как 32. Вероятно, здесь ошибка в отсутствии запятой и предполагалась высота 3.2, поэтому все значения больше 10м, я поделила на 10. Т.к. доля выбросов незначительна, оставляем их. По регламенту, высота потолков в принципе должна быть более 2.5м, средние показатели как раз и показывают это.**

# %% [markdown]
# ##### Параметр "Тип этажа квартиры"

# %%
new_df.groupby('type_floor')['type_floor'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='type_floor'>

# %% [markdown]
# **Данные выглядят правдоподобно. Могли возникнуть вопросы, если бы пик графика приходился на первый или последний этаж. Но пик графика на группе "другие" ожидаем. Оставляем данные как есть.**

# %% [markdown]
# ##### Параметр "Общее количество этажей в доме"

# %%
new_df['floors_total'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['floors_total'].describe()
# Out:
# count    21099.000000
# mean        10.763164
# std          6.636855
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
sns.boxplot(x=new_df['floors_total'])
# Out:
# <AxesSubplot:xlabel='floors_total'>

# %% [markdown]
# **В Санкт-Петербурге действует ограничения по высотной застройке, но т.к. таких данных немного, оставляем, на средние показатели это сильно не влияет.**

# %% [markdown]
# ##### Параметр "Расстояние до центра города в метрах"

# %%
new_df['city_centers_nearest'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['city_centers_nearest'].describe()
# Out:
# count    15703.000000
# mean     15119.453353
# std       8511.889301
# min        208.000000
# 25%      10764.000000
# 50%      13729.000000
# 75%      16788.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
sns.boxplot(x=new_df['city_centers_nearest'])
# Out:
# <AxesSubplot:xlabel='city_centers_nearest'>

# %%
p75 = np.percentile(new_df.loc[~new_df['city_centers_nearest'].isna(), 'city_centers_nearest'], 75)

# %%
p25 = np.percentile(new_df.loc[~new_df['city_centers_nearest'].isna(), 'city_centers_nearest'], 25)

# %%
IQR = p75-p25
IQR
# Out:
# 6024.0

# %%
IQR_max = IQR*1.5 + p75

# %%
IQR_min = p25-IQR*1.5

# %%
max_city_centre = new_df.query('city_centers_nearest > @IQR_max')
max_city_centre
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 10                9   3300000.0        44.0           2018-08-27      2
# 12               20   3550000.0        42.8           2017-07-01      2
# 13                1   4400000.0        36.0           2016-06-23      1
# 26                8   4170000.0        44.0           2017-12-13      1
# 31                8   4800000.0        73.0           2018-10-15      4
# ...             ...         ...         ...                  ...    ...
# 22607            14   9990000.0        90.0           2017-01-23      3
# 22609             8   3000000.0        34.1           2017-11-10      1
# 22618            10   3500000.0        43.0           2016-05-19      2
# 22624            15   2490000.0        31.0           2019-01-24      1
# 22632             9   4600000.0        62.4           2016-08-05      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
max_city_centre['locality_name'].unique()
# Out:
# array(['Ломоносов', 'Петергоф', 'Пушкин', 'Колпино', 'Кронштадт',
#        'поселок Металлострой', 'Сестрорецк', 'поселок Шушары',
#        'Красное Село', 'поселок Понтонный', 'Павловск', 'Санкт-Петербург',
#        'Зеленогорск', 'поселок Молодежное', 'поселок Песочный',
#        'поселок Петро-Славянка', 'поселок Саперный', 'поселок Щеглово',
#        'поселок Лисий Нос', 'поселок Белоостров', nan, 'поселок Репино',
#        'поселок Усть-Ижора', 'поселок Александровская'], dtype=object)

# %%
max_city_centre['last_price'].median()
# Out:
# 3900000.0

# %%
new_df['last_price'].median()
# Out:
# 4350000.0

# %%
min_city_centre = new_df.query('city_centers_nearest < @IQR_min')
min_city_centre.sort_values('last_price')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19017             4   2400000.0        12.0           2017-07-19      1
# 12268             0   3500000.0        46.0           2016-06-23      2
# 18925             0   3800000.0        13.0           2018-07-04      1
# 2341              1   4000000.0        39.0           2018-02-08      2
# 19577             1   4250000.0        30.0           2017-11-02      1
# ...             ...         ...         ...                  ...    ...
# 10596            13  10200000.0       114.8           2018-07-19      3
# 2300              9  10500000.0        85.0           2018-09-05      3
# 17532            16  10500000.0        73.8           2017-07-10      2
# 5930              0  10600000.0        85.0           2017-11-10      4
# 16480             6  10770000.0        82.0           2015-05-28      4
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
min_city_centre['last_price'].median()
# Out:
# 7970000.0

# %%
new_df['city_centers_nearest'].describe()
# Out:
# count    15703.000000
# mean     15119.453353
# std       8511.889301
# min        208.000000
# 25%      10764.000000
# 50%      13729.000000
# 75%      16788.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# **Мы проверили удаленность  квартир от городского центра. Сначала, проверили удаленные квартиры: преимущественно все они
# находятся в Ленинградской области. Выявили, чем более удалена квартира от центра, тем меньше у неё цена, что в дальнейшем может влиять при усреднении данных. Аналогично с квартирами в самом центре, их местоположение влияет на цену. Удалять данные не будет, т.к. в целом они отражают реальность. И если убирать данные, то фильтруя по конкретным районам есть риск исказить данные.**

# %% [markdown]
# ##### Параметр "Расстояние до ближайшего парка"

# %%
new_df['parks_nearest'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['parks_nearest'].describe()
# Out:
# count    6479.000000
# mean      487.521377
# std       323.249618
# min         1.000000
# 25%       290.000000
# 50%       456.000000
# 75%       613.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
sns.boxplot(x=new_df['parks_nearest'])
# Out:
# <AxesSubplot:xlabel='parks_nearest'>

# %%
p25 = np.percentile(new_df.loc[~new_df['parks_nearest'].isna(), 'parks_nearest'], 25)

# %%
p75 = np.percentile(new_df.loc[~new_df['parks_nearest'].isna(), 'parks_nearest'], 75)

# %%
IQR = p75-p25
IQR
# Out:
# 323.0

# %%
IQR_max = IQR*1.5 + p75

# %%
new_df.query('parks_nearest > @IQR_max')['last_price'].median()
# Out:
# 5350000.0

# %%
new_df.query('parks_nearest < @IQR_max')['last_price'].median()
# Out:
# 5141282.5

# %% [markdown]
# **Мы проанализировали столбец с отдаленностью квартир от парков, убрали выбросы. Также посмотрели значение медианы цены для квартир внутри межквартильного размаха и вне его. Предполагалось, что, чем ближе квартира к парку, тем она дороже, но по данным этого явно не видно. Поэтому оставляем данные как есть.**

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21171 entries, 1 to 22636
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21171 non-null  int64
#  1   last_price            21171 non-null  float64
#  2   total_area            21171 non-null  float64
#  3   first_day_exposition  21171 non-null  datetime64[ns]
#  4   rooms                 21171 non-null  int64
#  5   ceiling_height        21171 non-null  float64
#  6   floors_total          21099 non-null  float64
#  7   living_area           20811 non-null  float64
#  8   floor                 21171 non-null  int64
#  9   is_apartment          21171 non-null  object
#  10  studio                21171 non-null  bool
#  11  open_plan             21171 non-null  bool
#  12  kitchen_area          20424 non-null  float64
#  13  balcony               21171 non-null  float64
# ...

# %%
new_df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  21171.000000  2.117100e+04  21171.000000  21171.000000    21171.000000
# mean       9.647017  4.709190e+06     52.258029      1.913608        2.717443
# std        5.514670  2.047325e+06     17.547008      0.875828        0.197414
# min        0.000000  1.219000e+04     12.000000      1.000000        1.000000
# 25%        6.000000  3.300000e+06     38.870000      1.000000        2.600000
# 50%        9.000000  4.350000e+06     48.600000      2.000000        2.771499
# 75%       13.000000  5.884220e+06     62.500000      3.000000        2.771499
# max       39.000000  1.079000e+07    120.000000      6.000000        8.300000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  21099.000000  20811.000000  21171.000000  20424.000000  21171.000000
# mean      10.763164     29.951363      5.883331      9.450872      0.589061
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        0.986523
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.771499
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.771499
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total  living_area         floor  kitchen_area       balcony  \
# count  23613.000000  23260.00000  23699.000000  22885.000000  23699.000000
# mean      10.673824     34.51550      5.892358     10.566398      0.591080
# ...

# %% [markdown]
# **По итогам рассмотрения отдельно столбцов, мы избавились от 10% исходных данных, которые являлись выбросами.**

# %% [markdown]
# #### Изучение скорости продажи квартиры
# Изучите, как быстро продавались квартиры (столбец days_exposition).
# Этот параметр показывает, сколько дней было размещено каждое объявление.
# 1. Постройте гистограмму.
# 2. Посчитайте среднее и медиану.
# 3. В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?

# %%
new_df['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['days_exposition'].describe()
# Out:
# count    18620.00000
# mean       171.24334
# std        208.76346
# min          1.00000
# 25%         43.00000
# 50%         91.00000
# 75%        217.00000
# max       1580.00000
# Name: days_exposition, dtype: float64

# %%
sns.boxplot(x=new_df['days_exposition'])
# Out:
# <AxesSubplot:xlabel='days_exposition'>

# %%
p25 = np.percentile(new_df.loc[~new_df['days_exposition'].isna(), 'days_exposition'], 25)

# %%
p75 = np.percentile(new_df.loc[~new_df['days_exposition'].isna(), 'days_exposition'], 75)

# %%
IQR_max = (p75-p25)*1.5 + p75

# %%
test_df = new_df.query('days_exposition < @IQR_max').reset_index(drop=True)
test_df['days_exposition'].describe()
# Out:
# count    17060.000000
# mean       120.740445
# std        113.323742
# min          1.000000
# 25%         39.000000
# 50%         78.000000
# 75%        173.000000
# max        477.000000
# Name: days_exposition, dtype: float64

# %%
test_df['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
def days_category(row):
    days = row['days_exposition']

    if 0 <= days <= 39:
        return 'быстрая продажа'   
    if 21 <= days <= 100:
        return 'от 40 до 172 дней'
    if 173 <= days:
        return 'долгая продажа'

# %%
test_df['category'] = test_df.apply(days_category, axis=1)
test_df.pivot_table(index='category', values='days_exposition', aggfunc=('count', 'mean', 'median'))
# Out:
#                    count        mean  median
# category
# быстрая продажа     4301   19.209254    19.0
# долгая продажа      4281  288.745153   273.0
# от 40 до 172 дней   5578   63.667444    60.0

# %% [markdown]
# **Мы построили гистограмму распределения дней продажи квартир. Видно, что пик скорости продаж приходится на срок
# от 40 до 180 дней. Убрали из выборки аномально долгие продажи. Быстрыми продажами назовем те, которые закрываются быстрее чем 75 % остальных продаж. Долгими продажами назовём те, что за пределами 3 квартиля.**

# %% [markdown]
# #### Факторы, влияющие на стоимость
# Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта.
# Изучите, зависит ли цена от:
# 1. общей площади;
# 2. жилой площади;
# 3. площади кухни;
# 4. количества комнат;
# 5. этажа, на котором расположена квартира (первый, последний, другой);
# 6. даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.

# %%
addiction_df = new_df.loc[:,['last_price','total_area', 'living_area', 'kitchen_area']]

# %%
pd.plotting.scatter_matrix(addiction_df, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='last_price', ylabel='last_price'>,
#         <AxesSubplot:xlabel='total_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='living_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='total_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='living_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='living_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='living_area'>,
#         <AxesSubplot:xlabel='living_area', ylabel='living_area'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='living_area'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='kitchen_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='kitchen_area'>,
# ...

# %%
last_price_addiction = addiction_df.corr() 
last_price_addiction['last_price']
# Out:
# last_price      1.000000
# total_area      0.679036
# living_area     0.558019
# kitchen_area    0.467215
# Name: last_price, dtype: float64

# %%
df_type_floor = new_df.pivot_table(index='type_floor', values='last_price', aggfunc=('mean', 'median', 'count'))
df_type_floor
# Out:
#             count          mean     median
# type_floor
# другие      15481  4.898554e+06  4500000.0
# первый       2774  4.057751e+06  3800000.0
# последний    2916  4.323575e+06  4000000.0

# %%
df_type_floor.plot(y='median', figsize=(6, 6), kind='bar')
# Out:
# <AxesSubplot:xlabel='type_floor'>

# %%
new_df['day_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['month_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['year_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
new_df['rooms'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Согласно графикам и коэффициенту корреляции, наиболее сильно стоимость квартиры зависит от общей площади, и как следствие, от жилой площади и площади кухни. Следующий по силе фактор - количество комнат, особенно это видно по однокомнатным,  двуxкомнатным и трехкомнатным квартирам. Что касается года продажи, наименьшее количество сделок наблюдается по 2014 году, возможно, это обусловлено тем, что в то время еще не был так сильно распространен онлайн формат. Но в целом, высчитать зависимость цены от дня/месяца/года мы не можем, можем лишь посмотреть на количество сделок в определенный период, каких-то явных несоответствий по гистограммам мы не видим. Также можно заметить, что стоимость квартир на первом и последнем этаже в среднем будет меньше, нежели на любых других этажах.**
#
# Вопрос: правильно понимаю, что посчитать коэффициент корреляции для типа этажа невозможно и что бессмысленно смотреть на коэффициент корреляции day/month/year_exposition?

# %% [markdown]
# #### Средняя цена м2
# Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
pivot = new_df.pivot_table(index='locality_name', values=['first_day_exposition', 'price_per_meter'], aggfunc={'first_day_exposition':'count', 'price_per_meter':'mean'})
pivot = pivot.sort_values('first_day_exposition', ascending=False)
pivot.columns = ['count_announcements', 'price_per_meter']
pivot = pivot.head(10)
pivot
# Out:
#                    count_announcements  price_per_meter
# locality_name
# Санкт-Петербург                  13318    104864.820737
# поселок Мурино                     556     85681.762572
# поселок Шушары                     438     78623.524589
# Всеволожск                         393     67047.106845
# Пушкин                             336    100213.442321
# Колпино                            335     75221.876299
# поселок Парголово                  326     90332.262638
# Гатчина                            303     68664.035611
# деревня Кудрово                    298     92409.726309
# Выборг                             232     58229.729569

# %%
pivot.loc[pivot['price_per_meter'] == pivot['price_per_meter'].max()].index
# Out:
# Index(['Санкт-Петербург'], dtype='object', name='locality_name')

# %%
pivot.loc[pivot['price_per_meter'] == pivot['price_per_meter'].min()].index
# Out:
# Index(['Выборг'], dtype='object', name='locality_name')

# %% [markdown]
# **Мы выявили, что наибольшая цена за м.кв. в выборке в г. Санкт-Петербург, что также соотвествует и наибольшему количеству объявлений. Наименьшая цена за м.кв. в выборке в г. Выборг.**

# %% [markdown]
# #### Стоимость кв в зависимости от близости к центру
# Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра. Учитывайте каждый километр расстояния: узнайте среднюю цену квартир в одном километре от центра, в двух и так далее. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
city_centre_df = new_df.query('locality_name == "Санкт-Петербург"').pivot_table(index='city_centre_km', values='last_price')
city_centre_df
# Out:
#                   last_price
# city_centre_km
# 0.0             7.754686e+06
# 1.0             7.630328e+06
# 2.0             7.419185e+06
# 3.0             7.056048e+06
# 4.0             7.319487e+06
# 5.0             7.050061e+06
# 6.0             6.563198e+06
# 7.0             6.372615e+06
# 8.0             5.999704e+06
# 9.0             5.208330e+06
# 10.0            5.241220e+06
# 11.0            5.219431e+06
# 12.0            5.204210e+06
# 13.0            5.420719e+06
# 14.0            5.220420e+06
# 15.0            5.067898e+06
# 16.0            4.990925e+06
# 17.0            4.620607e+06
# 18.0            4.690598e+06
# 19.0            4.583555e+06
# 20.0            6.302553e+06
# 21.0            5.009030e+06
# 22.0            5.095368e+06
# 23.0            4.126867e+06
# 24.0            3.862235e+06
# 25.0            4.014913e+06
# 26.0            3.575000e+06
# 27.0            2.250000e+06
# 28.0            4.910500e+06
# 29.0            3.833333e+06

# %%
city_centre_df.plot(y='last_price', style='o-', xlim=(0, 30), grid=True, figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='city_centre_km'>

# %%
city_centre_df = new_df.query('locality_name == "Санкт-Петербург"').pivot_table(index='city_centre_km', columns='locality_name', values='last_price')
city_centre_df = city_centre_df.reset_index()
city_centre_df.columns = ['km', 'price']
city_centre_df.corr()
# Out:
#             km    price
# km     1.00000 -0.88419
# price -0.88419  1.00000

# %% [markdown]
# **Мы построили график и посчитали коэффициент корреляции стоимости квартиры с близостью к центру города, увидели вполне логичную закономерность: чем ближе квартира расположена к центру города, тем дороже она стоит.**

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы провели исследовательский анализ и выявили, какие именно факторы больше всего влияют на рыночную стоимость квартир. Наиболее значимыми факторами стали близость к центру, общая площадь квартиры и, как следствие, жилая площадь и площадь кухни. Также выявили зависимость стоимости квартиры от количества комнат.
# Также, полагаю, что есть смысл рассмотреть дополнительные факторы, как, например, наличие/отсутствие ремонта и в квартире и его состояние, год постройки дома, однако в данных нет информации об этом.**
